# %%
import numpy as np 
import sys
import pdb
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt 
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import f1_score
import math

# %%
def get_data(x_path, y_path):
    '''
    Args:
        x_path: path to x file
        y_path: path to y file
    Returns:
        x: np array of [NUM_OF_SAMPLES x n]
        y: np array of [NUM_OF_SAMPLES]
    '''
    x = x_path
    y = y_path

    y = np.load(y_path)
    x = np.load(x_path)

    #normalize x:
    x = 2*(0.5 - x/255)
    return x, y

def get_metric(y_true, y_pred):
    '''
    Args:
        y_true: np array of [NUM_SAMPLES x r] (one hot) 
                or np array of [NUM_SAMPLES]
        y_pred: np array of [NUM_SAMPLES x r] (one hot) 
                or np array of [NUM_SAMPLES]
                
    '''
    results = classification_report(y_pred, y_true)
    print(results)

if __name__ == '__main__':

    x_train_path = "D:/IIT Delhi Softwares-Documents/Sem2324/COL774/Assignment-3/q2/part b/x_train.npy"
    y_train_path = "D:/IIT Delhi Softwares-Documents/Sem2324/COL774/Assignment-3/q2/part b/y_train.npy"

    X_train, y_train = get_data(x_train_path, y_train_path)

    # x_test_path = sys.argv[3]
    # y_test_path = sys.argv[4]

    # X_test, y_test = get_data(x_test_path, y_test_path)

    #you might need one hot encoded y in part a,b,c,d,e
    label_encoder = OneHotEncoder(sparse_output = False)
    label_encoder.fit(np.expand_dims(y_train, axis = -1))

    y_train_onehot = label_encoder.transform(np.expand_dims(y_train, axis = -1))
    # y_test_onehot = label_encoder.transform(np.expand_dims(y_test, axis = -1))

# %%
X_train[0],X_train[1]
# Out:
# (array([ 0.21568627,  0.21568627,  0.21568627, ..., -0.19215686,
#         -0.15294118, -1.        ]),
#  array([ 0.21568627,  0.21568627,  0.22352941, ..., -0.19215686,
#         -0.15294118, -1.        ]))

# %%
losses=[]

# %%
import numpy as np

class NeuralNetwork:
    def __init__(self, input_size, hidden_layers, output_size):
        self.input_size = input_size
        self.hidden_layers = hidden_layers
        self.output_size = output_size
        self.weights, self.biases = self.initialize_weights_and_biases()
        
    def initialize_weights_and_biases(self):
        layers = [self.input_size] + self.hidden_layers + [self.output_size]
        weights = [np.random.randn(layers[i], layers[i + 1]) for i in range(len(layers) - 1)]
        biases = [np.zeros((1, layers[i + 1])) for i in range(len(layers) - 1)]
        return weights, biases

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))

    def softmax(self, x):
        exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))
        return exp_x / exp_x.sum(axis=1, keepdims=True)

    def forward(self, X):
        self.z = []
        self.a = [X]
        for i in range(len(self.weights) - 1):
            z = np.dot(self.a[-1], self.weights[i]) + self.biases[i]
            a = self.sigmoid(z)
            self.z.append(z)
            self.a.append(a)
        logits = np.dot(self.a[-1], self.weights[-1]) + self.biases[-1]
        probabilities = self.softmax(logits)
        return probabilities

    def backward(self, X, y, learning_rate, adaptive, epoch):
        m = X.shape[0]
        delta_weights = [np.zeros(w.shape) for w in self.weights]
        delta_biases = [np.zeros(b.shape) for b in self.biases]

        probabilities = self.forward(X)

        error = probabilities - y
        for i in range(len(self.weights) - 1, -1, -1):
            delta_weights[i] = np.dot(self.a[i].T, error) / m
            delta_biases[i] = np.sum(error, axis=0) / m
            if i > 0:
                error = np.dot(error, self.weights[i].T) * (self.a[i] * (1 - self.a[i]))

        for i in range(len(self.weights)):
            if adaptive== True:
                learning_rate= learning_rate/ (math.sqrt(epoch))
            self.weights[i] -= learning_rate * delta_weights[i]
            self.biases[i] -= learning_rate * delta_biases[i]

    def train(self, X, y, num_epochs, learning_rate, batch_size,adaptive):
        for epoch in range(num_epochs):
            for i in range(0, X.shape[0], batch_size):
                X_batch = X[i:i+batch_size]
                y_batch = y[i:i+batch_size]
                loss1 = self.cross_entropy_loss(y_batch, self.forward(X_batch))
                losses.append(loss1)
                self.backward(X_batch, y_batch, learning_rate, adaptive, epoch)
                loss2= self.cross_entropy_loss(y_batch, self.forward(X_batch))
                if(abs(loss2-loss1)<1e-4):
                    break
                

    def one_hot_encode(self, y, num_classes):
        return np.eye(num_classes)[y]

    def cross_entropy_loss(self, y_true, y_pred):
        return -np.sum(y_true * np.log(y_pred)) / len(y_true)
    
    def predict(self,X):
        probs= self.forward(X)
        y_pred= np.argmax(probs, axis=1)
        return y_pred +1

# %%
x_test_path = "D:/IIT Delhi Softwares-Documents/Sem2324/COL774/Assignment-3/q2/part b/x_test.npy"
y_test_path = "D:/IIT Delhi Softwares-Documents/Sem2324/COL774/Assignment-3/q2/part b/y_test.npy"

X_test, y_test = get_data(x_test_path, y_test_path)

# %%
input_size = 1024
hidden_layers = [512, 64, 64, 256, 128, 64]
output_size = 5
num_epochs = 50
learning_rate = 0.01
batch_size = 32

model = NeuralNetwork(input_size, hidden_layers, output_size)

model.train(X_train, y_train_onehot, num_epochs, learning_rate, batch_size, False)
y_preds= model.predict(X_train)
train_acc= np.sum(y_preds == y_train) / len(y_train) * 100
print(train_acc)

y_test_pred = model.predict(X_test)
y_test_pred = y_test_pred

test_acc= sum(y_test_pred == y_test)/ len(y_test) * 100
print(test_acc)
plt.plot(losses)
# Out:
# 69.25
# 66.0

# %% [markdown]
# Single Hidden Layer

# %%
hidden_layer_list= [1, 5, 10, 50, 100]

train_acc_list=[]
test_acc_list=[]

for hidden_layer in hidden_layer_list:
    input_size = 1024
    hiden_layers= [hidden_layer]
    output_size = 5
    num_epochs = 50
    learning_rate = 0.01
    batch_size = 32
    
    model = NeuralNetwork(input_size, hidden_layers, output_size)

    model.train(X_train, y_train_onehot, num_epochs, learning_rate,batch_size, False)
    
    y_preds= model.predict(X_train)
    train_acc= np.sum(y_preds == y_train) / len(y_train) * 100
    print(f"Train Accuracy for {hidden_layer} is:  {train_acc}")
    train_acc_list.append(train_acc)
    
    y_test_pred = model.predict(X_test)
    y_test_pred = y_test_pred

    test_acc= sum(y_test_pred == y_test)/ len(y_test) * 100
    print(f"Test Accuracy for {hidden_layer} is:  {test_acc}")
    test_acc_list.append(test_acc)
    
    plt.plot(losses)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title(f"For no of nodes in single hidden: {hidden_layer}")
    plt.show()
# Out:
# Train Accuracy for 1 is:  69.14
# Test Accuracy for 1 is:  66.2
# Train Accuracy for 5 is:  70.28
# Test Accuracy for 5 is:  66.2
# Train Accuracy for 10 is:  69.56
# Test Accuracy for 10 is:  66.7
# Train Accuracy for 50 is:  69.41000000000001
# Test Accuracy for 50 is:  64.8
# Train Accuracy for 100 is:  71.15
# Test Accuracy for 100 is:  68.8

# %%
f1_score(y_test, y_test_pred, average= 'weighted')
# Out:
# 0.6864103651554114

# %%
hidden_layer_depth_list= [[512],[512, 256], [512, 256, 128], [512, 256, 128, 64]]

train_acc_list=[]
test_acc_list=[]
f1_score_list=[]

for hidden_layer_depth in hidden_layer_depth_list:
    input_size = 1024
    hiden_layers= hidden_layer_depth
    output_size = 5
    num_epochs = 50
    learning_rate = 0.01
    batch_size = 32
    
    model = NeuralNetwork(input_size, hidden_layers, output_size)

    model.train(X_train, y_train_onehot, num_epochs, learning_rate, batch_size, False)
    
    y_preds= model.predict(X_train)
    train_acc= np.sum(y_preds == y_train) / len(y_train) * 100
    print(f"Train Accuracy for Hidden Layer Depth {hidden_layer_depth} is:  {train_acc}")
    train_acc_list.append(train_acc)
    
    y_test_pred = model.predict(X_test)

    test_acc= sum(y_test_pred == y_test)/ len(y_test) * 100
    print(f"Test Accuracy for Hidden Layer Depth {hidden_layer_depth} is:  {test_acc}")
    test_acc_list.append(test_acc)
    
    f1= f1_score(y_test, y_test_pred,average= 'weighted')
    f1_score_list.append(f1)
    
    plt.plot(losses)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title(f"For depth {hidden_layer} of hidden layers")
    plt.show()
    
    
plt.plot(f1)
plt.xlabel("Hidden Layer Depths")
plt.ylabel("F1 Scores")
# Out:
# Train Accuracy for Hidden Layer Depth [512] is:  68.86
# Test Accuracy for Hidden Layer Depth [512] is:  66.60000000000001
# Train Accuracy for Hidden Layer Depth [512, 256] is:  69.13
# Test Accuracy for Hidden Layer Depth [512, 256] is:  67.80000000000001
# Train Accuracy for Hidden Layer Depth [512, 256, 128] is:  69.38
# Test Accuracy for Hidden Layer Depth [512, 256, 128] is:  65.10000000000001
# Train Accuracy for Hidden Layer Depth [512, 256, 128, 64] is:  69.88
# Test Accuracy for Hidden Layer Depth [512, 256, 128, 64] is:  65.7
# Text(0, 0.5, 'F1 Scores')

# %%
hidden_layer_depth_list= [[512],[512, 256], [512, 256, 128], [512, 256, 128, 64]]

train_acc_list=[]
test_acc_list=[]
f1_score_list=[]

for hidden_layer_depth in hidden_layer_depth_list:
    input_size = 1024
    hidden_layers= hidden_layer_depth
    output_size = 5
    num_epochs = 50
    learning_rate = 0.01
    batch_size = 32
    
    model = NeuralNetwork(input_size, hidden_layers, output_size)

    model.train(X_train, y_train_onehot, num_epochs, learning_rate,True,  batch_size)
    
    y_preds= model.predict(X_train)
    train_acc= np.sum(y_preds == y_train) / len(y_train) * 100
    print(f"Train Accuracy for Hidden Layer Depth {hidden_layer_depth} is:  {train_acc}")
    train_acc_list.append(train_acc)
    
    y_test_pred = model.predict(X_test)

    test_acc= sum(y_test_pred == y_test)/ len(y_test) * 100
    print(f"Test Accuracy for Hidden Layer Depth {hidden_layer_depth} is:  {test_acc}")
    test_acc_list.append(test_acc)
    
    f1= f1_score(y_test, y_test_pred,average= 'weighted')
    f1_score_list.append(f1)
    
    plt.plot(losses)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title(f"For depth {hidden_layer} of hidden layers")
    plt.show()
    
    
    plt.plot(f1)
    plt.xlabel("Hidden Layer Depths")
    plt.ylabel("F1 Scores")
# Out:
# Train Accuracy for Hidden Layer Depth [512] is:  70.24000000000001
# Test Accuracy for Hidden Layer Depth [512] is:  66.10000000000001
# Train Accuracy for Hidden Layer Depth [512, 256] is:  74.57000000000001
# Test Accuracy for Hidden Layer Depth [512, 256] is:  74.8
# Train Accuracy for Hidden Layer Depth [512, 256, 128] is:  76.94
# Test Accuracy for Hidden Layer Depth [512, 256, 128] is:  75.7
# Train Accuracy for Hidden Layer Depth [512, 256, 128, 64] is:  76.5
# Test Accuracy for Hidden Layer Depth [512, 256, 128, 64] is:  75.2

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
hidden_layer_depth_list= [(512),(512, 256), (512, 256, 128), (512, 256, 128, 64)]

for hidden_layer_depth in hidden_layer_depth_list:

    hidden_layer_sizes = hidden_layer_depth 
    activation = 'relu'
    solver = 'sgd'
    alpha = 0
    batch_size = 32
    learning_rate = 'invscaling'
    max_iter = 1000  
    tolerance = 1e-4  

    # Create the MLPClassifier model
    mlp = MLPClassifier(    
        hidden_layer_sizes=hidden_layer_sizes,
        activation=activation,
        solver=solver,
        alpha=alpha,
        batch_size=batch_size,
        learning_rate=learning_rate,
        max_iter=max_iter,
        tol=tolerance,
        random_state=42  
    )
    
    mlp.fit(X_train, y_train)
    y_pred = mlp.predict(X_test)
    
    accuracy = accuracy_score(y_test, y_pred)
    classification_rep = classification_report(y_test, y_pred)

    print("Accuracy:", accuracy)
    print("Classification Report:\n", classification_rep)

    # Plot the training loss curve
    plt.plot(mlp.loss_curve_)
    plt.xlabel("Iteration")
    plt.ylabel("Loss")
    plt.title("Training Loss Curve")
    plt.show()
# Out:
# Accuracy: 0.558
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.76      0.91      0.83       229
#            2       0.52      0.42      0.46       198
#            3       0.42      0.34      0.37       199
#            4       0.40      0.30      0.34       187
#            5       0.55      0.77      0.64       187
#
#     accuracy                           0.56      1000
#    macro avg       0.53      0.55      0.53      1000
# weighted avg       0.54      0.56      0.54      1000
# Accuracy: 0.593
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.80      0.87      0.83       229
#            2       0.56      0.49      0.52       198
#            3       0.48      0.42      0.45       199
#            4       0.44      0.37      0.40       187
#            5       0.59      0.75      0.66       187
#
#     accuracy                           0.59      1000
#    macro avg       0.57      0.58      0.57      1000
# weighted avg       0.58      0.59      0.58      1000
# Accuracy: 0.605
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.84      0.89      0.86       229
#            2       0.60      0.55      0.57       198
#            3       0.48      0.46      0.47       199
#            4       0.42      0.39      0.40       187
#            5       0.60      0.69      0.64       187
#
#     accuracy                           0.60      1000
#    macro avg       0.59      0.59      0.59      1000
# weighted avg       0.60      0.60      0.60      1000
# Accuracy: 0.612
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.85      0.87      0.86       229
#            2       0.59      0.58      0.58       198
#            3       0.51      0.50      0.50       199
#            4       0.43      0.40      0.42       187
#            5       0.61      0.66      0.64       187
#
#     accuracy                           0.61      1000
#    macro avg       0.60      0.60      0.60      1000
# weighted avg       0.61      0.61      0.61      1000
